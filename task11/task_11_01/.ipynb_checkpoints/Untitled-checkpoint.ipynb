# %%
import pandas as pd
import matplotlib.pyplot as plt


# %matplotlib inline

# Загрузка данных из файла olympics.csv
df = pd.read_csv('olympics.csv', skiprows=4)

# На какой дистанции Jesse Owens выиграл медаль?
cn = "OWENS, Jesse"
jesse_owens_medal_event = df[df["Athlete"] == cn]["Event"].values[0]
print(f"Jesse Owens выиграл медаль в событии: {jesse_owens_medal_event}")
# Out:
# Jesse Owens выиграл медаль в событии: 100m

# %%
# Мужчины какой страны взяли большинство золотых медалей в бадминтоне?
sport = "Badminton"
badminton_gold_medals = df[(df["Sport"] == sport) & (df["Medal"] == "Gold")]
most_gold_medals_country = badminton_gold_medals[
    badminton_gold_medals["Gender"] == "Men"]["NOC"].mode()[0]
print(f"Мужчины из страны {most_gold_medals_country}")
# Out:
# Мужчины из страны INA

# %%
# Какие три страны получили наибольшее количество медалей в последние
# годы (с 1984 по 2008)?
recent_years = range(1984, 2009)
recent_medals = df[df["Edition"].isin(recent_years)]
top_countries = recent_medals["NOC"].value_counts().head(3)
print("Топ-3 страны с наибольшим количеством медалей в последние годы:")
print(top_countries)
# Out:
# Топ-3 страны с наибольшим количеством медалей в последние годы:
# NOC
# USA    1837
# AUS     762
# GER     691
# Name: count, dtype: int64

# %%
# Найдите мужчин - золотых медалистов по 100m. Выведите город, год, имя атлета
# и страну, за которую он выступал.
men_100m_gold_medalists = df[
    (df["Event"] == "100m") & (df["Medal"] == "Gold") & (df["Gender"] == "Men")
    ]
result = men_100m_gold_medalists[
    ["City", "Edition", "Athlete", "NOC"]
    ].sort_values(by="Edition", ascending=False)
print("Мужчины-золотые медалисты по 100m:")
print(result)
# Out:
# Мужчины-золотые медалисты по 100m:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# 9009   Melbourne / Stockholm     1956  MORROW, Robert Joseph  USA
# 8121                Helsinki     1952        REMIGINO, Lindy  USA
# 7302                  London     1948      DILLARD, Harrison  USA
# 6427                  Berlin     1936           OWENS, Jesse  USA
# 5806             Los Angeles     1932           TOLAN, Eddie  USA
# 5095               Amsterdam     1928        WILLIAMS, Percy  CAN
# 4236                   Paris     1924       ABRAHAMS, Harold  GBR
# 2996                 Antwerp     1920       PADDOCK, Charles  USA
# 2022               Stockholm     1912           CRAIG, Ralph  USA
# 1191                  London     1908       WALKER, Reginald  RSA
# 737                 St Louis     1904           HAHN, Archie  USA
# 231                    Paris     1900        JARVIS, Francis  USA
# 13                    Athens     1896          BURKE, Thomas  USA

# %%
# Используя groupby(), постройте график - число всех медалей, выигранных на
# каждой Олимпиаде.
medals_by_year = df.groupby("Edition")["Medal"].count()
medals_by_year.plot(kind="bar", figsize=(10, 5))
plt.xlabel("Год Олимпиады")
plt.ylabel("Количество медалей")
plt.title("Число всех медалей по годам")
plt.show()

# %%
# Создайте список, показывающий число всех медалей, полученных каждой страной в
# течение всей истории Олимпийских игр.
# Для каждой страны покажите год первой и последней заработанной медали.
medals_by_country = df.groupby("NOC").agg(
    {"Medal": "count", "Edition": ["min", "max"]})
medals_by_country.columns = ["Total Medals", "First Year", "Last Year"]
medals_by_country = medals_by_country.reset_index()
print("Статистика медалей по странам:")
print(medals_by_country)
# Out:
# Статистика медалей по странам:
#      NOC  Total Medals  First Year  Last Year
# 0    AFG             1        2008       2008
# 1    AHO             1        1988       1988
# 2    ALG            14        1984       2008
# 3    ANZ            29        1908       1912
# 4    ARG           239        1924       2008
# ..   ...           ...         ...        ...
# 133  VIE             2        2000       2008
# 134  YUG           435        1924       2000
# 135  ZAM             2        1984       1996
# 136  ZIM            23        1980       2008
# 137  ZZX            48        1896       1904
#
# [138 rows x 4 columns]

# %%
# Постройте график - число золотых медалей, выигранных мужчинами и женщинами из
# США в атлетике.
usa_athletics = df[(df["NOC"] == "USA") & (df["Sport"] == "Athletics")]
usa_gold_medals_by_gender = usa_athletics.groupby("Gender")["Medal"].count()
usa_gold_medals_by_gender.plot(kind="bar", figsize=(8, 5))
plt.xlabel("Пол")
plt.ylabel("Количество золотых медалей")
plt.title("Золотые медали в атлетике для мужчин и женщин из США")
plt.show()

# %%
# Постройте таблицу, где по годам всех Олимпиад покажите атлетов США
# (один атлет на год), топовых по общему количеству медалей.
# Также укажите дисциплину, в которой выступал атлет.
usa_athletes_by_year = df[df["NOC"] == "USA"].groupby(
    ["Edition", "Athlete", "Discipline"])["Medal"].count().reset_index()
usa_top_athletes_by_year = usa_athletes_by_year.groupby("Edition").apply(
    lambda x: x[x["Medal"] == x["Medal"].max()])
print("Топ-атлеты США по годам:")
print(usa_top_athletes_by_year)
# Out:
# Топ-атлеты США по годам:
#               Edition                           Athlete     Discipline  Medal
# Edition
# 1896    5        1896                   GARRETT, Robert      Athletics      4
# 1900    14       1900                    BAXTER, Irving      Athletics      5
#         47       1900         TEWKSBURY, Walter B. John      Athletics      5
# 1904    101      1904                   DOWNING, Burton  Cycling Track      6
#         117      1904                     EYSER, George    Artistic G.      6
#         155      1904                      HEIDA, Anton    Artistic G.      6
# 1908    369      1908                  SHEPPARD, Melvin      Athletics      3
#         370      1908                  SHERIDAN, Martin      Athletics      3
# 1912    428      1912             OSBURN, Carl Townsend       Shooting      4
# 1920    514      1920                       LEE, Willis       Shooting      7
#         567      1920            SPOONER, Lloyd Spencer       Shooting      7
# 1924    617      1924                  EDERLE, Gertrude       Swimming      3
#         705      1924                 RICHARDS, Vincent         Tennis      3
#         743      1924               WEISSMULLER, Johnny       Swimming      3
# 1928    759      1928            BARBUTI, Raymond James      Athletics      2
#         773      1928               COLEMAN, Georgia V.         Diving      2
#         783      1928  DESJARDINS, Ulise Joseph "Peter"         Diving      2
#         789      1928           GALITZEN, Michael Riley         Diving      2
#         797      1928              KOJAC, George Harold       Swimming      2
#         800      1928                    LAUFER, Walter       Swimming      2
#         810      1928                  NORELIUS, Martha       Swimming      2
#         811      1928            OSIPOWICH, Albina Lucy       Swimming      2
#         814      1928               ROBINSON, Elizabeth      Athletics      2
#         816      1928                  SAVILLE, Eleanor       Swimming      2
#         823      1928               WEISSMULLER, Johnny       Swimming      2
# 1932    871      1932                DIDRIKSON, Mildred      Athletics      3
#         927      1932                   MADISON, Helene       Swimming      3
# 1936    1040     1936                      OWENS, Jesse      Athletics      4
# 1948    1099     1948             CURTIS, Ann Elisabeth       Swimming      3
#         1112     1948             EWELL, Harold Norwood      Athletics      3
#         1142     1948           MCLANE, James Price Jr.       Swimming      3
#         1193     1948         WHITFIELD, Malvin Groston      Athletics      3
# 1952    1249     1952               KONNO, Ford Hiroshi       Swimming      3
# 1956    1325     1956               BAKER, Walter Thane      Athletics      3
#         1334     1956              BREEN, George Thomas       Swimming      3
#         1394     1956             MORROW, Robert Joseph      Athletics      3
# 1960    1515     1960       VON SALTZA, Susan Christina       Swimming      4
# 1964    1563     1964                   ELLIS, Kathleen       Swimming      4
#         1625     1964        SCHOLLANDER, Donald Arthur       Swimming      4
#         1634     1964             STOUDER, Sharon Marie       Swimming      4
# 1968    1686     1968                 HENNE, Jane Margo       Swimming      4
#         1688     1968         HICKCOX, Charles Buchanan       Swimming      4
#         1718     1968              PEDERSEN, Susan Jane       Swimming      4
#         1738     1968                       SPITZ, Mark       Swimming      4
# 1972    1859     1972                       SPITZ, Mark       Swimming      7
# 1976    1885     1976         BABASHOFF, Shirley Farber       Swimming      5
#         1966     1976              NABER, John Phillips       Swimming      5
# 1984    2222     1984                  RETTON, Mary-Lou    Artistic G.      5
# 1988    2309     1988                   BIONDI, Matthew       Swimming      7
# 1992    2582     1992                   MILLER, Shannon    Artistic G.      5
# 1996    2718     1996                    HALL, Gary Jr.       Swimming      4
#         2773     1996                    MARTINO, Angel       Swimming      4
#         2855     1996                    VAN DYKEN, Amy       Swimming      4
# 2000    3060     2000                      TORRES, Dara       Swimming      5
# 2004    3241     2004                   PHELPS, Michael       Swimming      8
# 2008    3478     2008                   PHELPS, Michael       Swimming      8
